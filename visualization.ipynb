# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
chest_metadata = pd.read_csv("NIH/Data_Entry_2017.csv")
chest_metadata
# Out:
#              Image Index          Finding Labels  Follow-up #  Patient ID  \
# 0       00000001_000.png            Cardiomegaly            0           1
# 1       00000001_001.png  Cardiomegaly|Emphysema            1           1
# 2       00000001_002.png   Cardiomegaly|Effusion            2           1
# 3       00000002_000.png              No Finding            0           2
# 4       00000003_000.png                  Hernia            0           3
# ...                  ...                     ...          ...         ...
# 112115  00030801_001.png          Mass|Pneumonia            1       30801
# 112116  00030802_000.png              No Finding            0       30802
# 112117  00030803_000.png              No Finding            0       30803
# 112118  00030804_000.png              No Finding            0       30804
# 112119  00030805_000.png              No Finding            0       30805
#
#         Patient Age Patient Gender View Position  OriginalImage[Width  \
# ...

# %%
chest_metadata.describe()
# Out:
#          Follow-up #     Patient ID    Patient Age  OriginalImage[Width  \
# count  112120.000000  112120.000000  112120.000000        112120.000000
# mean        8.573751   14346.381743      46.901463          2646.078844
# std        15.406320    8403.876972      16.839923           341.246429
# min         0.000000       1.000000       1.000000          1143.000000
# 25%         0.000000    7310.750000      35.000000          2500.000000
# 50%         3.000000   13993.000000      49.000000          2518.000000
# 75%        10.000000   20673.000000      59.000000          2992.000000
# max       183.000000   30805.000000     414.000000          3827.000000
#
#              Height]  OriginalImagePixelSpacing[x             y]
# count  112120.000000                112120.000000  112120.000000
# mean     2486.438842                     0.155649       0.155649
# std       401.268227                     0.016174       0.016174
# ...

# %%
# Remove empty Column
chest_metadata.drop(['Unnamed: 11'], axis=1, inplace=True)

# %% [markdown]
# # Column Unique Value Count Visualization

# %% [markdown]
# ## Top 10 Labels

# %%
 = chest_metadata['Finding Labels'].value_counts()

# %%
label_count[:10].plot(kind='bar', figsize=(10,5), rot=0)
plt.xlabel('Label', fontsize = 14)
plt.ylabel('Count', fontsize = 14)
plt.xticks(rotation=75)
plt.title('Top 10 Labels within the Dataset', fontsize= 16)
plt.savefig('images_made/Top10Labels.png', dpi=300, bbox_inches = 'tight')

# %%
total_top = label_count[:10].sum()
total_bottom = label_count[10:].sum()

fig = plt.figure(figsize= (7,5))
plt.bar(['Top 10', 'Rest'], [total_top, total_bottom], width=0.3)
plt.ylabel('Count', fontsize = 14)
plt.xticks(fontsize = 14)
plt.title('Sum of Top 10 Labels and The Rest', fontsize = 16)
plt.savefig('images_made/SumTop10AndRest.png', dpi = 300, bbox_inches = 'tight')

# %%
del total_top, total_bottom, label_count

# %% [markdown]
# ## Age Histogram

# %%
plt.hist(chest_metadata['Patient Age'], bins=20)
plt.show()

# %% [markdown]
# It appears that some inputs have their age wrongly inputted. Ages beyond 100 and

# %%
# Out:
# 58
# 56
# 52
# 55
# 57
# 54
# 53
# 51
# 59
# 46
# 49
# 45
# 50
# 60
# 48
# 47
# 61
# 44
# 62
# 63
# 65
# 43
# 64
# 40
# 66
# 42
# 34
# 39
# 35
# 32
# 33
# 67
# 30
# 31
# 38
# 41
# 28
# 37
# 36
# 29
# 24
# 68
# 23
# 27
# 25
# 22
# 26
# 69
# 21
# 70
# 20
# 71
# 73
# 72
# 19
# 18
# 16
# 74
# 17
# 75
# 76
# 15
# 14
# 77
# 13
# 10
# 9
# 11
# 78
# 12
# 79
# 80
# 81
# 7
# 6
# 8
# 83
# 5
# 82
# 4
# 3
# 2
# 87
# 86
# 85
# 84
# 89
# 90
# 88
# 1
# 91
# 93
# 94
# 92
# 412
# 148
# 155
# 414
# 95
# 150
# 149
# 152
# 151
# 411
# 413
# 153
# 154
